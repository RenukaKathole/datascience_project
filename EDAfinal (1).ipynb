# %%
#Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset with correct separator
df = pd.read_csv("/content/pronostico_dataset (1).csv", sep=';')

# %%
df
# Out:
#         ID        age  systolic_bp  diastolic_bp  cholesterol       prognosis
# 0        0  77.196340    85.288742     80.021878    79.957109     retinopathy
# 1        1  63.529850    99.379736     84.852361   110.382411     retinopathy
# 2        2  69.003986   111.349455    109.850616   100.828246     retinopathy
# 3        3  82.638210    95.056128     79.666851    87.066303     retinopathy
# 4        4  78.346286   109.154591     90.713220    92.511770     retinopathy
# ...    ...        ...          ...           ...          ...             ...
# 5995  5995  49.611850    94.857639     86.615671   107.643986  no_retinopathy
# 5996  5996  63.099686   100.039527     93.515186   104.971404     retinopathy
# 5997  5997  55.562243    98.421446    102.697875   120.875951     retinopathy
# 5998  5998  63.468956   106.809289     88.060631   106.052213     retinopathy
# 5999  5999  62.506825    96.900784     86.878033   108.625436  no_retinopathy
#
# [6000 rows x 6 columns]

# %%
# Display the first 5 rows
df.head()
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy

# %%
# Shape of the dataset
df.shape
# Out:
# (6000, 6)

# %%
# Info about data types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            6000 non-null   int64
#  1   age           6000 non-null   float64
#  2   systolic_bp   6000 non-null   float64
#  3   diastolic_bp  6000 non-null   float64
#  4   cholesterol   6000 non-null   float64
#  5   prognosis     6000 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 281.4+ KB

# %%
# Column names
df.columns
# Out:
# Index(['ID', 'age', 'systolic_bp', 'diastolic_bp', 'cholesterol', 'prognosis'], dtype='object')

# %%
#Data Types like int or flot
df.dtypes
# Out:
# ID                int64
# age             float64
# systolic_bp     float64
# diastolic_bp    float64
# cholesterol     float64
# prognosis        object
# dtype: object

# %%
# Descriptive statistics
df.describe()
# Out:
#                 ID          age  systolic_bp  diastolic_bp  cholesterol
# count  6000.000000  6000.000000  6000.000000   6000.000000  6000.000000
# mean   2999.500000    60.464121   100.694822     90.505547   100.628255
# std    1732.195139     8.564392    10.669267      9.648200    10.433915
# min       0.000000    35.164761    69.675429     62.807105    69.967453
# 25%    1499.750000    54.371941    93.267420     83.641788    93.202373
# 50%    2999.500000    59.831159   100.119926     89.912429   100.060637
# 75%    4499.250000    65.809652   107.439501     96.682405   107.250829
# max    5999.000000   103.279497   151.699660    133.456382   148.233544

# %%
# Check for missing values
df.isnull().sum()
# Out:
# ID              0
# age             0
# systolic_bp     0
# diastolic_bp    0
# cholesterol     0
# prognosis       0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#prognosis: (0 or 1) (Target). It is 1 if the patient has retinopathy and 0 if he doesn't.
df['prognosis'].unique()
# Out:
# array(['retinopathy', 'no_retinopathy'], dtype=object)

# %%
# Drop 'ID' column as it doesn’t help in prediction
df.drop('ID', axis=1, inplace=True)

# %%
df
# Out:
#             age  systolic_bp  diastolic_bp  cholesterol       prognosis
# 0     77.196340    85.288742     80.021878    79.957109     retinopathy
# 1     63.529850    99.379736     84.852361   110.382411     retinopathy
# 2     69.003986   111.349455    109.850616   100.828246     retinopathy
# 3     82.638210    95.056128     79.666851    87.066303     retinopathy
# 4     78.346286   109.154591     90.713220    92.511770     retinopathy
# ...         ...          ...           ...          ...             ...
# 5995  49.611850    94.857639     86.615671   107.643986  no_retinopathy
# 5996  63.099686   100.039527     93.515186   104.971404     retinopathy
# 5997  55.562243    98.421446    102.697875   120.875951     retinopathy
# 5998  63.468956   106.809289     88.060631   106.052213     retinopathy
# 5999  62.506825    96.900784     86.878033   108.625436  no_retinopathy
#
# [6000 rows x 5 columns]

# %%
#1.Histogram plot

# %%
sns.histplot(df['age'],kde=True)
plt.title("Age Distribution")
plt.show()

# %%
# Define feature columns (excluding target)
#prognosis: (0 or 1) (Target). It is 1 if the patient has retinopathy and 0 if he doesn't.
features = ['age', 'systolic_bp', 'diastolic_bp', 'cholesterol']
target = 'prognosis'

# %%
for column in features:
    sns.histplot(df[column], kde=True, color='skyblue')
    plt.title(f'{column.capitalize()} Histogram')
    plt.show()

# %%
#2.Boxplot

# %%
for column in features:
    sns.boxplot(y=df[column], color='lightcoral')
    plt.title(f'{column.capitalize()} Boxplot')
    plt.show()

# %%
# 3. Violin Plot

# %%
for column in features:
    sns.violinplot(x=target, y=column, data=df, palette='Set3')
    plt.title(f'{column.capitalize()} vs {target.capitalize()} (Violin Plot)')
    plt.show()
# Out:
# /tmp/ipython-input-87-3504660401.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=target, y=column, data=df, palette='Set3')
# /tmp/ipython-input-87-3504660401.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=target, y=column, data=df, palette='Set3')
# /tmp/ipython-input-87-3504660401.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=target, y=column, data=df, palette='Set3')
# /tmp/ipython-input-87-3504660401.py:2: FutureWarning:
#
# ...

# %%
#4. Bar Plot (Mean by Target)

# %%
for column in features:
    sns.barplot(x=target, y=column, data=df, palette='Set2')
    plt.title(f'Mean {column.capitalize()} by {target.capitalize()}')
    plt.show()
# Out:
# /tmp/ipython-input-89-1193584078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target, y=column, data=df, palette='Set2')
# /tmp/ipython-input-89-1193584078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target, y=column, data=df, palette='Set2')
# /tmp/ipython-input-89-1193584078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=target, y=column, data=df, palette='Set2')
# /tmp/ipython-input-89-1193584078.py:2: FutureWarning:
#
# ...

# %%
#5. Regplot (vs Cholesterol)

# %%
for column in features:
    if column != 'cholesterol':
        sns.regplot(x=df[column], y=df['cholesterol'], scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
        plt.title(f'{column.capitalize()} vs Cholesterol (Regplot)')
        plt.show()

# %%
#6. Scatterplot

# %%
sns.scatterplot(x="systolic_bp",y="diastolic_bp",hue="cholesterol",data=df)
# Out:
# <Axes: xlabel='systolic_bp', ylabel='diastolic_bp'>

# %%
#7. Line Plot by Age (sorted)

# %%
df_sorted = df.sort_values('age')
for column in features:
    sns.lineplot(x=df_sorted['age'], y=df_sorted[column], color='green')
    plt.title(f'{column.capitalize()} vs Age (Lineplot)')
    plt.show()

# %%
#8. Heatmap

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr = numeric_df.corr()

# %%
sns.heatmap(corr, annot=True,cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
 #9. Pairplot

# %%
sns.pairplot(df, hue=target)
plt.suptitle("Pair Plot of Features")
plt.show()

# %%
#10. Pie Chart of Target Class

# %%
class_counts = df[target].value_counts()
labels = ['No Retinopathy', 'Retinopathy']
plt.pie(class_counts, labels=labels, autopct='%1.1f%%', colors=['lightgreen', 'salmon'], startangle=140)
plt.title("Prognosis Class Distribution (Pie Chart)")
plt.axis('equal')
plt.show()
